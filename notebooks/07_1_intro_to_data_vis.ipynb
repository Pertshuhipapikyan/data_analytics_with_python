# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
pd.options.display.float_format = "{:,.2f}".format

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/dummy_data.csv')
df.head()
# Out:
#    customer_id  age region       segment    income  monthly_spend
# 0            1   56   West  Medium Value 63,353.00       2,411.00
# 1            2   69   East  Medium Value 64,900.00       2,688.00
# 2            3   46   East     Low Value 47,074.00       1,147.00
# 3            4   32  North    High Value 30,267.00       1,671.00
# 4            5   60  North    High Value 44,233.00       2,753.00

# %% [markdown]
# ### Grammer of Graphics
#
#     1. Data: df
#     2. Aesthetics
#         A. x-axis:
#         B. y-axis:

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from statsmodels) (2.4.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from statsmodels) (3.0.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U nbformat
# Out:
# Requirement already satisfied: nbformat in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\User\anaconda3\envs\myenv\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

fig = px.scatter(
    data_frame=df, # data
    x="age", # x aesthetic
    y="income", # y aesthetic
    color="segment", # color aesthetic
    size="monthly_spend", # size aesthetic
    # facet_row ="region", # facet

    facet_col="region",
    trendline="ols", # statistical layer
    title="Relationship Between Customer Age and Income"
)

fig.show()

# %%
grouping = ["region","segment"]
sales_by_region= df.groupby(grouping, as_index = False).agg(
     total_sales= ('monthly_spend', 'sum'),
     avg_age= ('age', 'mean'),
     avg_income= ('income', 'mean'),
     number_of_customers= ('customer_id', 'count')
)
sales_by_region.head()
# Out:
#   region       segment  total_sales  avg_age  avg_income  number_of_customers
# 0   East    High Value    30,380.00    35.64   45,427.64                   11
# 1   East     Low Value    41,203.00    39.44   51,505.31                   32
# 2   East  Medium Value    45,082.00    46.14   54,797.90                   21
# 3  North    High Value    37,696.00    40.93   44,810.29                   14
# 4  North     Low Value    36,642.00    45.08   56,712.85                   26

# %%
Y = list(sales_by_region.columns)[len(grouping):]
Y
# Out:
# ['total_sales', 'avg_age', 'avg_income', 'number_of_customers']

# %%
Y = ['total_sales', 'avg_age', 'avg_income', 'number_of_customers']

for i in Y:
    fig= px.bar(
        data_frame= sales_by_region,
        x= 'region',
        y=i,
        title= f'{i} by Region'
    )
    fig.show()

# %% [markdown]
# ### Matplotlib for Instacart

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_parquet('../data/processed/instacart.parquet')
df.head()
# Out:
#    order_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899            11          4                  8
# 1   1187899            11          4                  8
# 2   1187899            11          4                  8
# 3   1187899            11          4                  8
# 4   1187899            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  department  ... Surname  Gender  \
# 0                              Soda    9.00   beverages  ...  Nguyen  Female
# 1             Organic String Cheese    8.60  dairy eggs  ...  Nguyen  Female
# 2          0% Greek Strained Yogurt   12.60  dairy eggs  ...  Nguyen  Female
# 3  XL Pick-A-Size Paper Towel Rolls    1.00   household  ...  Nguyen  Female
# 4            Milk Chocolate Almonds    6.80      snacks  ...  Nguyen  Female
#
#      state Age date_joined  n_dependants fam_status  income region  \
# 0  Alabama  31   2/17/2019             3    married   40423  South
# 1  Alabama  31   2/17/2019             3    married   40423  South
# 2  Alabama  31   2/17/2019             3    married   40423  South
# 3  Alabama  31   2/17/2019             3    married   40423  South
# 4  Alabama  31   2/17/2019             3    married   40423  South
#
#              division
# 0  East South Central
# 1  East South Central
# 2  East South Central
# 3  East South Central
# 4  East South Central
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (1384706, 22)

# %%
df.describe().iloc[:,1]
# Out:
# count   1,384,706.00
# mean           17.09
# std            16.61
# min             4.00
# 25%             6.00
# 50%            11.00
# 75%            21.00
# max           100.00
# Name: order_number, dtype: float64

# %%
df.describe()
# Out:
#           order_id  order_number    order_dow  order_hour_of_day  \
# count 1,384,706.00  1,384,706.00 1,384,706.00       1,384,706.00
# mean  1,706,297.96         17.09         2.70              13.58
# std     989,734.21         16.61         2.17               4.24
# min           1.00          4.00         0.00               0.00
# 25%     843,370.00          6.00         1.00              10.00
# 50%   1,701,880.00         11.00         3.00              14.00
# 75%   2,568,023.00         21.00         5.00              17.00
# max   3,421,070.00        100.00         6.00              23.00
#
#        days_since_prior_order  add_to_cart_order    reordered       prices  \
# count            1,384,706.00       1,384,706.00 1,384,706.00 1,384,618.00
# mean                    17.07               8.76         0.60        14.12
# std                     10.43               7.42         0.49       680.23
# min                      0.00               1.00         0.00         1.00
# 25%                      7.00               3.00         0.00         4.30
# 50%                     15.00               7.00         1.00         7.40
# 75%                     30.00              12.00         1.00        11.30
# max                     30.00              80.00         1.00    99,999.00
#
#                Age  n_dependants       income
# count 1,384,706.00  1,384,706.00 1,384,706.00
# mean         49.38          1.50    97,662.28
# std          18.44          1.12    41,991.39
# min          18.00          0.00    25,911.00
# 25%          33.00          0.00    64,859.00
# 50%          49.00          1.00    95,765.00
# 75%          65.00          2.00   126,817.75
# max          81.00          3.00   591,089.00

# %%
df.head()
# Out:
#    order_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899            11          4                  8
# 1   1187899            11          4                  8
# 2   1187899            11          4                  8
# 3   1187899            11          4                  8
# 4   1187899            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  department  ... Surname  Gender  \
# 0                              Soda    9.00   beverages  ...  Nguyen  Female
# 1             Organic String Cheese    8.60  dairy eggs  ...  Nguyen  Female
# 2          0% Greek Strained Yogurt   12.60  dairy eggs  ...  Nguyen  Female
# 3  XL Pick-A-Size Paper Towel Rolls    1.00   household  ...  Nguyen  Female
# 4            Milk Chocolate Almonds    6.80      snacks  ...  Nguyen  Female
#
#      state Age date_joined  n_dependants fam_status  income region  \
# 0  Alabama  31   2/17/2019             3    married   40423  South
# 1  Alabama  31   2/17/2019             3    married   40423  South
# 2  Alabama  31   2/17/2019             3    married   40423  South
# 3  Alabama  31   2/17/2019             3    married   40423  South
# 4  Alabama  31   2/17/2019             3    married   40423  South
#
#              division
# 0  East South Central
# 1  East South Central
# 2  East South Central
# 3  East South Central
# 4  East South Central
#
# [5 rows x 22 columns]

# %%
df_dow= (
    df[['order_id','order_dow']].
    drop_duplicates().
    groupby("order_dow").
    size()
)
df_dow
# Out:
# order_dow
# 0    27465
# 1    19672
# 2    16119
# 3    15687
# 4    15959
# 5    17406
# 6    18901
# dtype: int64

# %%
type(df_dow)
# Out:
# pandas.Series

# %%
X = df_dow.index
Y = df_dow.values

# %%
type(Y)
# Out:
# numpy.ndarray

# %%
type(X)
# Out:
# pandas.Index

# %%
plt.figure()
plt.bar(x=X,height = Y)
plt.title("Number of Orders by Day of Week")
plt.xlabel("Days of Week")
plt.ylabel("Number of Orders")
plt.show()

# %%
df_hod = (
    df[['order_id','order_hour_of_day']]
    .drop_duplicates()
    .groupby('order_hour_of_day')
    .size()
    )


df_hod
# Out:
# order_hour_of_day
# 0       852
# 1       507
# 2       305
# 3       223
# 4       218
# 5       402
# 6      1121
# 7      3376
# 8      6343
# 9      9033
# 10    10585
# 11    10610
# 12    10622
# 13    10711
# 14    11103
# 15    11075
# 16    10495
# 17     9353
# 18     7558
# 19     5721
# 20     3978
# 21     3050
# 22     2442
# 23     1526
# dtype: int64

# %%
X=df_hod.index
Y=df_hod.values
plt.figure()
plt.bar(x=X, height=Y)
plt.title("Number of Orders by Day of Week")
plt.xlabel("Days of Week")
plt.ylabel("Number of Orders")
plt.show()

# %%
df.head()
# Out:
#    order_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899            11          4                  8
# 1   1187899            11          4                  8
# 2   1187899            11          4                  8
# 3   1187899            11          4                  8
# 4   1187899            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  department  ... Surname  Gender  \
# 0                              Soda    9.00   beverages  ...  Nguyen  Female
# 1             Organic String Cheese    8.60  dairy eggs  ...  Nguyen  Female
# 2          0% Greek Strained Yogurt   12.60  dairy eggs  ...  Nguyen  Female
# 3  XL Pick-A-Size Paper Towel Rolls    1.00   household  ...  Nguyen  Female
# 4            Milk Chocolate Almonds    6.80      snacks  ...  Nguyen  Female
#
#      state Age date_joined  n_dependants fam_status  income region  \
# 0  Alabama  31   2/17/2019             3    married   40423  South
# 1  Alabama  31   2/17/2019             3    married   40423  South
# 2  Alabama  31   2/17/2019             3    married   40423  South
# 3  Alabama  31   2/17/2019             3    married   40423  South
# 4  Alabama  31   2/17/2019             3    married   40423  South
#
#              division
# 0  East South Central
# 1  East South Central
# 2  East South Central
# 3  East South Central
# 4  East South Central
#
# [5 rows x 22 columns]

# %%
df_hod= (
    df[['order_id','order_hour_of_day']]
    .drop_duplicates()
    .groupby('order_hour_of_day')
    .size()
    )
df_hod
# Out:
# order_hour_of_day
# 0       852
# 1       507
# 2       305
# 3       223
# 4       218
# 5       402
# 6      1121
# 7      3376
# 8      6343
# 9      9033
# 10    10585
# 11    10610
# 12    10622
# 13    10711
# 14    11103
# 15    11075
# 16    10495
# 17     9353
# 18     7558
# 19     5721
# 20     3978
# 21     3050
# 22     2442
# 23     1526
# dtype: int64

# %%
X=df_hod.index
Y=df_hod.values
plt.figure()
plt.bar(x=X, height=Y)
plt.title('Number of orders By hour of the day')
plt.xlabel("Hour of the day")
plt.ylabel("Number of Orders")
plt.show()

# %%
top_departments  = df['department'].value_counts().head(10)

top_departments
# Out:
# department
# produce            409087
# dairy eggs         217051
# snacks             118862
# beverages          113962
# frozen             100426
# pantry              81242
# bakery              48394
# canned goods        46799
# deli                44291
# dry goods pasta     38713
# Name: count, dtype: int64

# %%
N = 5

if df['department'].value_counts().shape[0] > 10:
    departments  = df['department'].value_counts().head(N)
else:
    departments  = df['department'].value_counts().tail(N)

# %%
X = departments.index
Y = departments.values




plt.figure()
plt.bar(x=X,height = Y)
plt.title("Top 10 Departments")
plt.xlabel("Departments")
plt.ylabel("Number of Orders")
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure()
plt.barh(y=X,width= Y)
plt.title("Top 10 Departments")
plt.xlabel("Departments")
plt.ylabel("Number of Orders")
plt.xticks(rotation = 45)
plt.show()

# %%
df['prices'].describe()
# Out:
# count   1,384,618.00
# mean           14.12
# std           680.23
# min             1.00
# 25%             4.30
# 50%             7.40
# 75%            11.30
# max        99,999.00
# Name: prices, dtype: float64

# %%
plt.figure()
plt.hist(df['prices'].dropna())
plt.title("Top 10 Departments")
plt.xlabel("Price")
plt.Artist()
plt.ylabel("Frequency")
plt.xticks(rotation = 45)
plt.show()

# %%
upper_limit = df['prices'].quantile(0.99)
upper_limit
# Out:
# np.float64(18.1)

# %%
df_prices_q= df[df['prices']<= 18.1]
df_prices_q["prices"].describe()
# Out:
# count   1,370,887.00
# mean            7.67
# std             4.04
# min             1.00
# 25%             4.20
# 50%             7.30
# 75%            11.20
# max            18.10
# Name: prices, dtype: float64

# %%
plt.figure()
plt.hist(df_prices_q['prices'].dropna())
plt.title("Top 10 Departments")
plt.xlabel("Price")
plt.Artist()
plt.ylabel("Frequency")
plt.xticks(rotation = 45)
plt.show()

# %%
df['prices'].describe()
# Out:
# count   1,384,618.00
# mean           14.12
# std           680.23
# min             1.00
# 25%             4.30
# 50%             7.40
# 75%            11.30
# max        99,999.00
# Name: prices, dtype: float64

# %%
plt.figure()
plt.hist(df_prices_q["prices"].dropna(), bins=17)
plt.title("Distribution of Product Prices (Zoomed X-Axis)")
plt.xlabel("Price")
# plt.Artist()
plt.ylabel("Frequency")
plt.xticks(rotation = 45)
plt.show()
